# %%
Задание 1

Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
- оценка 2 и меньше - низкий рейтинг
- оценка 4 и меньше - средний рейтинг
- оценка 4.5 и 5 - высокий рейтинг

Результат классификации запишите в столбец class

# %%
import pandas as pd

# %%
def class_(param):
    if param <= 2.0:
        return 'низкий рейтинг'
    if param <= 4.0:
        return 'средний рейтинг'
    if param > 4:
        return 'высокий рейтинг'

# %%
ratings = pd.read_csv('ratings.csv')
movies = pd.read_csv('movies.csv')
joined = ratings.merge(movies, on='movieId', how='left')
df = joined.filter(items = ['title', 'rating'])
df['class_'] = df['rating'].apply(class_)
df.tail()

# %%
Задание 2

Используем файл keywords.csv.

Необходимо написать гео-классификатор, который каждой строке сможет 
выставить географическую принадлежность определенному региону. 
Т. е. если поисковый запрос содержит название города региона,
то в столбце ‘region’ пишется название этого региона. 
Если поисковый запрос не содержит названия города, то ставим ‘undefined’.

Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:

geo_data = {

'Центр': ['москва', 'тула', 'ярославль'],

'Северо-Запад': ['петербург', 'псков', 'мурманск'],

'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
}

Результат классификации запишите в отдельный столбец region.

# %%
geo_data = {'Center': ['москва', 'тула', 'ярославль'],'Zapad': ['петербург', 'псков', 'мурманск'],
'Vostok': ['владивосток', 'сахалин', 'хабаровск']}
 
df = pd.DataFrame({'Center': ['москва', 'тула', 'ярославль'],'Zapad': ['петербург', 'псков', 'мурманск'],
'Vostok': ['владивосток', 'сахалин', 'хабаровск']})
df
# Out:
#       Center      Zapad       Vostok
# 0     москва  петербург  владивосток
# 1       тула      псков      сахалин
# 2  ярославль   мурманск    хабаровск

# %%
# key = 'псков'
# def reg (param):
#     for i in df.columns:
#         newDf = df.loc[lambda df: df[i] == param]
#         if(not newDf.empty):
#             return i
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-275af0ba2d5d> in <module>
#       6 #             return i
#       7
# ----> 8 df.rows
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
def reg (param):
    if 'москва' in param:
        return 'Центр'
    if 'тула' in param:
        return 'Центр'
    if 'ярославль' in param:
        return 'Центр'
    if 'петербург' in param:
        return 'Северо-Запад'
    if 'псков' in param:
        return 'Северо-Запад'
    if 'мурманск' in param:
        return 'Северо-Запад'
    if 'владивосток' in param:
        return 'Дальний Восток'
    if 'сахалин' in param:
        return 'Дальний Восток'
    if 'хабаровск' in param:
        return 'Дальний Восток'
    else:
        return 'Undefined'

# %%
# a = []
# for value in geo_data.values():
#     a += value
# print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-7abba03b9061> in <module>
#       1 a = {}
#       2 for value in geo_data.values():
# ----> 3     a += value
#       4
#
# TypeError: unsupported operand type(s) for +=: 'dict' and 'list'

# %%
# def reg (param):
#     if a in param:
#         for i in df.columns:
#             newDf = df.loc[lambda df: df[i] == a[q]]
#             if(not newDf.empty):
#                 return i

# %%
# def loc ():
#     for i in df.columns:
#         newDf = df.loc[lambda df: df[i] == a[3]]
#         if(not newDf.empty):
#             return i
        
# loc()

# %%
towns = pd.read_csv('keywords.csv')
towns['region'] = towns['keyword'].apply(reg)
towns.head(30)
# Out:
#                           keyword     shows     region
# 0                  москва столица  64292780      Центр
# 1                              вк  64292779  Undefined
# 2                   одноклассники  63810309  Undefined
# 3                           порно  41747114  Undefined
# 4                            ютуб  39995567  Undefined
# 5                       вконтакте  21014195  Undefined
# 6      одноклассники моя страница  19976138  Undefined
# 7                            майл  15144673  Undefined
# 8                           авито  14786593  Undefined
# 9                      переводчик  14453469  Undefined
# 10                         яндекс  13344734  Undefined
# 11                сбербанк онлайн  10725673  Undefined
# 12                           mail   7687204  Undefined
# 13                           игры   6075762  Undefined
# 14                        youtube   5729958  Undefined
# 15         вконтакте моя страница   5971451  Undefined
# 16                           секс   5431732  Undefined
# 17                           гугл   5175471  Undefined
# 18                             dr   4880955  Undefined
# 19                    алиэкспресс   4879645  Undefined
# 20                        рамблер   4540421  Undefined
# 21                    фильмы 2016   4486635  Undefined
# 22                         погода   4344510  Undefined
# 23                             vk   4330448  Undefined
# 24              ютуб видеохостинг   4215267  Undefined
# 25                          дойки   4133424  Undefined
# 26  одноклассники социальная сеть   4018230  Undefined
# 27                       мультики   3866664  Undefined
# 28                        контакт   3815111  Undefined
# 29                        фейсбук   3669993  Undefined

# %%
Задание 3 (бонусное)

Есть мнение, что “раньше снимали настоящее кино, не то что сейчас”. 
Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из прошлого домашнего 
занятия (файл ratings.csv из базы https://grouplens.org/datasets/movielens). 
Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.

При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, 
а пройдемся по следующему алгоритму:

В переменную years запишите список из всех годов с 1950 по 2010.

Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. 
Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:

для каждой строки пройдите по всем годам списка years
если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец ‘year’

Посчитайте средний рейтинг всех фильмов для каждого значения столбца ‘year’ и 
отсортируйте результат по убыванию рейтинга

# %%
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
joined = ratings.merge(movies, on='movieId', how='left')
joined.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
#
#                                             title  \
# 0                          Dangerous Minds (1995)
# 1                                    Dumbo (1941)
# 2                                 Sleepers (1996)
# 3                     Escape from New York (1981)
# 4  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
#
#                              genres
# 0                             Drama
# 1  Animation|Children|Drama|Musical
# 2                          Thriller
# 3  Action|Adventure|Sci-Fi|Thriller
# 4                             Drama

# %%
YEARS = list(range(2010, 1949, -1))
print(YEARS[1])
# Out:
# 2009

# %%
joined['year'] = joined['title'].apply(reg)
joined.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-935e620c8a5b> in <module>
# ----> 1 joined['year'] = joined['title'].apply(reg)
#       2 joined.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-100-9f4b5b5f8432> in reg(param)
#       1 def reg (param):
# ----> 2     if YEARS[1] in param:
#       3         return YEARS[1]
#
# TypeError: 'in <string>' requires string as left operand, not int

# %%
def reg (param):
    if YEARS[1] in param:
        return YEARS[1]
