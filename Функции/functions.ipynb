# %% [markdown]
# Вы работаете секретарем и вам постоянно приходят различные документы. Вы должны быть очень внимательны, чтобы не потерять ни один документ. Каталог документов хранится в следующем виде:

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

# %% [markdown]
# Перечень полок, на которых находятся документы хранится в следующем виде:

# %%
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
directories = {'1': ['2207 876234', '11-2'],'2': ['10006'],'3': ['1']}

def people (documents):
    num = input('insert document number')
    for data in documents:
        if num == data['number']:
            result = (data['name'])
            return result
        else:
            result = 'document is not found'
    return result
    print(result)
# people()
#p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит; 

def shelf (directories):
    num = input('insert document number')
    for shelf in directories.items():
        if num in shelf[1]:
            result = (shelf[0])
            return result
    return ('not found')

# #s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится

def lists (documents):
    for data in documents:
        print(data['type'], data['number'],data['name'])

# #l – list – команда, которая выведет список всех документов 

def new_shelf (directories):
    newshelf = input('insert new shelf number')
    if newshelf not in directories.keys():
        directories[newshelf] = []
        result = directories
    else:
        result = ('shelf number already exists')
    return result

# #as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень

def delete (documents, directories):
    num = input('insert document number')
    for data in documents:
        if num == data['number']:
            del(data['number'])
            for shelf in directories.items():
                if num in shelf[1]:
                    list1 = shelf[1]
                    result = list1.remove(num)
            return documents, directories
    return ('Document does not exist')
 
# #d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок. Предусмотрите сценарий, когда пользователь вводит несуществующий документ; 

def move (documents, directories):
    doc_num = input('Insert document number')
    shelf_num = input('Insert shelf number where to move')
    if shelf_num in directories:
        for shelf in directories.items():
            if doc_num in shelf[1]:
                list1 = shelf[1]
                list1.remove(doc_num)
                directories[shelf_num] += [doc_num]
                result = directories
                return result
    else:
        result = ('Shelf or document do not exist')
        return result

# #m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую. Корректно обработайте кейсы, когда пользователь пытается переместить несуществующий документ или переместить документ на несуществующую полку; 

def add (documents, directories):
    doc_num = input('Insert document number')
    type_doc = input('Insert document type')
    name = input('Insert owner name')
    shelf_num = input('Insert shelf number')
    new_doc = {}
    new_doc ['type'] =  type_doc
    new_doc ['number'] =  doc_num
    new_doc ['name'] =  name
    documents.append(new_doc)
    directories[shelf_num] += [doc_num]
    result = documents, directories
    return result

# #a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться.


def main():
    while True:
        user_input = input('Insert command')
        if user_input == 'P':
            print(people(documents))
        elif user_input == 'S':
            print(shelf(directories))
        elif user_input == 'L':
            print(lists(documents))
        elif user_input == 'AS':
            print(new_shelf(directories))
        elif user_input == 'D':
            print(delete(documents, directories))
        elif user_input == 'M':
            print(move(documents, directories))
        elif user_input == 'A':
            print(add(documents, directories))   
        elif user_input == 'Q':
            print('See you soon!')
        break

main()
# Out:
# Insert commandQ
# See you soon!

# %% [markdown]
# Необходимо реализовать пользовательские команды (внимание! это не название функций, которые должны быть выразительными, а команды, которые вводит пользователь, чтобы получить необходимый результат):
#
# - p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
# - s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится
# Правильно обработайте ситуацию, когда пользователь будет вводить несуществующий документ.
# - l – list – команда, которая выведет список всех документов в формате
# **passport "2207 876234" "Василий Гупкин"**
# - as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень
# - d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок. Предусмотрите сценарий, когда пользователь вводит несуществующий документ;
# - m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую. Корректно обработайте кейсы, когда пользователь пытается переместить несуществующий документ или переместить документ на несуществующую полку;
# - a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться.
